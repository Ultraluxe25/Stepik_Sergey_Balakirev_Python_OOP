# %% [markdown]
# ## Аннотация типов - это информационный инструмент для программистов

# %% [markdown]
# ### Можно использовать Алиас для аннотации типов:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Тип Optional[1 тип] - это тип Union[1 тип, None]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Тип Final служит для констант (которые лучше не менять)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Для каждого объекта в кортеже нужно указывать тип отдельно
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Если все элементы кортежа принадлежат единому типу и их больше двух, то можно прописать их аннотацию вот так:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Для словарей в типах квадратных скобок указываем два типа - первый для ключа, второй для значения:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Для множества мы тоже указываем единственный тип
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Можно сделать глубоко упакованную аннотацию
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Сallable - аннотация вызываемого типа на функцию, `Callable[[int], str]`, где str - возврвщаемый тип
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Всегда лучше использовать тип Any чем object
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Если нужно аннотировать тип как объект класса, внутри определения самого класса, то нужно импортировать `annotations`. В старом способе класс как тип брался в кавычки, например `-> "Point2D":`
# ![image.png](attachment:image.png)
