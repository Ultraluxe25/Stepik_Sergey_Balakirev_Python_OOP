# %% [markdown]
# ![image.png](attachment:55a36826-f4df-4957-a965-8f7dca80aa58.png)

# %% [markdown]
# ### Сергей Балакирев предлагает пройти курс за 3-4 месяца (нормальный темп)

# %% [markdown]
# ### Локальный атрибут - это атрибут объекта класса (локальные свойства)

# %% [markdown]
# ![image.png](attachment:9bbc65ce-c44a-4221-b31c-7f623d7e7c4b.png)

# %% [markdown]
# ### Нужно научиться локально дебажить код в VS Code и пользоваться расширениями Qodo и Continue

# %% [markdown]
# ### После того как решил задачу обязательно посмотри топ 3-5 лучших решений и разбери их, может даже локально

# %% [markdown]
# ### С каждым новым проектом на работе нужно изучать что-то новое

# %% [markdown]
# ### После этого курса Балакирев рекомендует разобраться в паттернах проектирования. Я считаю что после него можно учиться реализовывать модели, методы и метрики основных моделей машинного обучения

# %% [markdown]
# # По мнению Сергей: "Хороший джун бы прошел этот курс за 1-2 недели, максимум за 3". Причем это он говорил в 2022 году, когда еще не было ChatGPT и других LLM. Думаю что сейчас это можно сделать быстрее

# %% [markdown]
# ### Очень важно уметь воспринимать и интерпретировать ТЗ (техническое задание)

# %% [markdown]
# ![image.png](attachment:98fa613f-150e-4b8f-af0d-55eac0d4d418.png)
# ### Это я иду разваливать все преграды на своем пути :)
